# %%
import pandas as pd
import matplotlib.pyplot as plt
import streamlit as st

# %%
dados = pd.read_csv("vendas_eletronicos.csv", encoding="utf-8")

# %%
dados.head()
# Out:
#    ID_Venda           Data_Venda                            ID_Cliente  \
# 0         1  2025-07-25 18:22:30  ad7a6b97-0c23-4887-93d8-009d551d2c86
# 1         2  2025-02-04 20:26:12  d27441c5-bd5e-4062-b291-aa3e771bf2b4
# 2         3  2025-01-13 05:41:58  bf3d7e95-83ba-4703-b15e-ec9987ca7c9b
# 3         4  2025-01-23 14:49:02  41c9cb5c-7490-4aaa-b2dc-d04f057acfb0
# 4         5  2024-12-13 00:31:42  4ba7746b-55d3-41cf-8a4f-f4f626451a61
#
#                    Nome_Cliente                     Email_Cliente  \
# 0                    Noël Dupuy            noël.dupuy@outlook.com
# 1                           김수민                 김수민.김수민@gmail.com
# 2             Charlotte Lévêque     charlotte.lévêque@hotmail.com
# 3  Маргарита Оскаровна Назарова      маргарита.назарова@yahoo.com
# 4          Filipa Vieira-Garcia  filipa.vieira-garcia@outlook.com
#
#              País Categoria_Produto                    Produto  \
# 0         Ouganda         Celulares             Google Pixel 6
# 1          우즈베키스탄         Celulares             OnePlus 10 Pro
# 2         Namibie        Acessórios           Carregador USB-C
# 3  Великобритания         Celulares             Google Pixel 6
# 4     Afeganistão        Acessórios  Protetor de tela de vidro
#
#    Preço_Unitário  Quantidade  Total_Venda
# 0           699.0           1        699.0
# 1           750.0           1        750.0
# 2            25.0           5        125.0
# 3           699.0           5       3495.0
# 4            10.0           3         30.0
