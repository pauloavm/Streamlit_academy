# %%
import pandas as pd
import matplotlib.pyplot as plt
import streamlit as st

# %%
dados = pd.read_csv("vendas_eletronicos.csv", encoding="utf-8")

# %%
dados.head()
# Out:
#    ID_Venda           Data_Venda                            ID_Cliente  \
# 0         1  2025-01-10 06:29:18  cd0ff065-d934-4ca7-8221-cc32836e88d3
# 1         2  2025-03-17 18:45:03  6de1cb89-d10e-43cd-84db-831abb94ed3c
# 2         3  2024-12-11 23:43:54  a5ff0aec-6ad6-4a7c-9a11-b9838e99db34
# 3         4  2024-11-12 23:44:36  aee49ce6-9ee7-44b9-8026-383df5d629b8
# 4         5  2025-04-01 14:23:05  174c8cfa-45a4-412b-b2f9-9826205d3c07
#
#                Nome_Cliente             Email_Cliente          País  \
# 0             Guillaume Rey  margotgerard@example.net       Somalie
# 1          Véronique Moreno       gdumont@example.net        Égypte
# 2            Josué Caldeira       diogo05@example.com  Santa Helena
# 3             Michael Chang  grimesrobert@example.net       Senegal
# 4  Justus Steinberg-Siering  seifertahmad@example.com    Westsahara
#
#   Categoria_Produto                   Produto  Preço_Unitário  Quantidade  \
# ...
